# %% [markdown]
# # Hyperparameter - Trajectory Relationship
# This simulation is intended to demonstrate the impacts of environmental hyperparameters on the ergodic trajectories generated.

# %%
import Pkg; Pkg.activate(""); Pkg.instantiate()
# Out:
#   Activating project at `~/Kaleb_Data/PhD_Research/CPS_Project/adaptive-ocean-exploration-sim`

# %%
using Logging: global_logger
using TerminalLoggers: TerminalLogger
global_logger(TerminalLogger())

using ProgressLogging

# %%
using Plots, Revise, StaticArrays, Interpolations, LinearAlgebra

# %%
include("src/kf.jl")
include("src/ngpkf.jl")
include("src/SyntheticData.jl")
include("src/ergodic.jl")
include("src/simulator_spatial.jl")
# Out:
# WARNING: method definition for #simulate_prerec_traj#12 at /home/dasc-group/Kaleb_Data/PhD_Research/CPS_Project/adaptive-ocean-exploration-sim/src/simulator_temp.jl:269 declares type variable XS but does not use it.
# WARNING: method definition for simulate_prerec_traj at /home/dasc-group/Kaleb_Data/PhD_Research/CPS_Project/adaptive-ocean-exploration-sim/src/simulator_temp.jl:269 declares type variable X but does not use it.
# WARNING: method definition for simulate_prerec_traj at /home/dasc-group/Kaleb_Data/PhD_Research/CPS_Project/adaptive-ocean-exploration-sim/src/simulator_temp.jl:269 declares type variable X but does not use it.
# Main.SimulatorTemp

# %% [markdown]
# ## Spatial-only Matern-12 Kernel

# %%
# Define domain vars
dim = 100; # number of data points along each axis in the domain (defining a square domain)
xstart, xstop = 0, 25; # x-axis start and end positions
ystart, ystop = 0, 10; # y-axis start and end positions

σ_sq = 1.0
λₓ = 1/(4.0) 

env_data = SyntheticData.matern12_spatial(dim, xstart, xstop, ystart, ystop, σ_sq, λₓ);
# heatmap(range(xstart, stop=xstop, length=dim), range(ystart, stop=ystop, length=dim), env_data; c = :vik)
# title!("Synthetic Data: σ² = $(σ_sq), λₓ = $(λₓ)")

# %%
plotly();
heatmap(env_data.X, env_data.Y, env_data.W', cmap = :balance; plottype=:wx)
plot!(clims=(-2,2))
# Out:
# ┌ Warning: Failed to load integration with PlotlyBase & PlotlyKaleido.
# │   exception =
# │    ArgumentError: Package PlotlyBase not found in current path.
# │    - Run `import Pkg; Pkg.add("PlotlyBase")` to install the PlotlyBase package.
# │    Stacktrace:
# │      [1] macro expansion
# │        @ Base ./loading.jl:1766 [inlined]
# │      [2] macro expansion
# │        @ Base ./lock.jl:267 [inlined]
# │      [3] __require(into::Module, mod::Symbol)
# │        @ Base ./loading.jl:1747
# │      [4] #invoke_in_world#3
# │        @ Base ./essentials.jl:921 [inlined]
# │      [5] invoke_in_world
# │        @ Base ./essentials.jl:918 [inlined]
# │      [6] require(into::Module, mod::Symbol)
# │        @ Base ./loading.jl:1740
# │      [7] top-level scope
# │        @ ~/.julia/packages/Plots/ju9dp/src/backends.jl:565
# │      [8] eval
# │        @ ./boot.jl:385 [inlined]
# │      [9] _initialize_backend(pkg::Plots.PlotlyBackend)
# │        @ Plots ~/.julia/packages/Plots/ju9dp/src/backends.jl:564
# │     [10] backend
# │        @ Plots ~/.julia/packages/Plots/ju9dp/src/backends.jl:244 [inlined]
# │     [11] plotly()
# │        @ Plots ~/.julia/packages/Plots/ju9dp/src/backends.jl:87
# │     [12] top-level scope
# │        @ In[6]:1
# │     [13] eval
# │        @ ./boot.jl:385 [inlined]
# │     [14] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
# │        @ Base ./loading.jl:2070
# │     [15] softscope_include_string(m::Module, code::String, filename::String)
# │        @ SoftGlobalScope ~/.julia/packages/SoftGlobalScope/u4UzH/src/SoftGlobalScope.jl:65
# │     [16] execute_request(socket::ZMQ.Socket, msg::IJulia.Msg)
# │        @ IJulia ~/.julia/packages/IJulia/Vo51o/src/execute_request.jl:67
# │     [17] #invokelatest#2
# │        @ ./essentials.jl:887 [inlined]
# │     [18] invokelatest
# │        @ ./essentials.jl:884 [inlined]
# │     [19] eventloop(socket::ZMQ.Socket)
# │        @ IJulia ~/.julia/packages/IJulia/Vo51o/src/eventloop.jl:8
# │     [20] (::IJulia.var"#15#18")()
# │        @ IJulia ~/.julia/packages/IJulia/Vo51o/src/eventloop.jl:38
# └ @ Plots /home/dasc-group/.julia/packages/Plots/ju9dp/src/backends.jl:574
#     <div id="bb4d61d4-bbe6-4c89-9f5a-82c48260ca21" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['plotly'], function (Plotly) {
#
#     Plotly.newPlot('bb4d61d4-bbe6-4c89-9f5a-82c48260ca21', [
#     {
#         "showlegend": false,
#         "xaxis": "x",
#         "colorbar": {
#             "y": 0.513888888888889,
#             "title": "",
#             "len": 0.9525371828521435,
#             "x": 0.7615339749198018
#         },
#         "name": "y1",
#         "plottype": "wx",
#         "colorscale": [
#             [
#                 0.0,
#                 "rgba(24, 28, 67, 1.000)"
#             ],
#             [
#                 0.00392156862745098,
#                 "rgba(25, 30, 70, 1.000)"
#             ],
#             [
#                 0.00784313725490196,
#                 "rgba(26, 31, 73, 1.000)"
#             ],
#             [
#                 0.011764705882352941,
#                 "rgba(27, 33, 76, 1.000)"
#             ],
#             [
#                 0.01568627450980392,
#                 "rgba(28, 34, 79, 1.000)"
#             ],
#             [
#                 0.0196078431372549,
#                 "rgba(29, 35, 82, 1.000)"
#             ],
#             [
#                 0.023529411764705882,
#                 "rgba(30, 37, 85, 1.000)"
#             ],
#             [
#                 0.027450980392156862,
#                 "rgba(31, 38, 88, 1.000)"
#             ],
#             [
#                 0.03137254901960784,
#                 "rgba(32, 39, 91, 1.000)"
#             ],
#             [
#                 0.03529411764705882,
#                 "rgba(33, 41, 95, 1.000)"
#             ],
#             [
#                 0.0392156862745098,
#                 "rgba(33, 42, 98, 1.000)"
#             ],
#             [
#                 0.043137254901960784,
#                 "rgba(34, 43, 101, 1.000)"
#             ],
#             [
#                 0.047058823529411764,
#                 "rgba(35, 45, 105, 1.000)"
#             ],
#             [
#                 0.050980392156862744,
#                 "rgba(36, 46, 108, 1.000)"
#             ],
#             [
#                 0.054901960784313725,
#                 "rgba(37, 47, 111, 1.000)"
#             ],
#             [
#                 0.058823529411764705,
#                 "rgba(37, 48, 115, 1.000)"
#             ],
#             [
#                 0.06274509803921569,
#                 "rgba(38, 50, 118, 1.000)"
#             ],
#             [
#                 0.06666666666666667,
#                 "rgba(39, 51, 122, 1.000)"
#             ],
#             [
#                 0.07058823529411765,
#                 "rgba(39, 52, 125, 1.000)"
#             ],
#             [
#                 0.07450980392156863,
#                 "rgba(40, 54, 129, 1.000)"
#             ],
#             [
#                 0.0784313725490196,
#                 "rgba(40, 55, 132, 1.000)"
#             ],
#             [
#                 0.08235294117647059,
#                 "rgba(41, 56, 136, 1.000)"
#             ],
#             [
#                 0.08627450980392157,
#                 "rgba(41, 58, 140, 1.000)"
#             ],
#             [
#                 0.09019607843137255,
#                 "rgba(41, 59, 143, 1.000)"
#             ],
#             [
#                 0.09411764705882353,
#                 "rgba(41, 60, 147, 1.000)"
#             ],
#             [
#                 0.09803921568627451,
#                 "rgba(41, 62, 151, 1.000)"
#             ],
#             [
#                 0.10196078431372549,
#                 "rgba(41, 63, 154, 1.000)"
#             ],
#             [
#                 0.10588235294117647,
#                 "rgba(41, 64, 158, 1.000)"
#             ],
#             [
#                 0.10980392156862745,
#                 "rgba(41, 66, 162, 1.000)"
#             ],
#             [
#                 0.11372549019607843,
#                 "rgba(40, 67, 165, 1.000)"
#             ],
#             [
#                 0.11764705882352941,
#                 "rgba(39, 69, 169, 1.000)"
#             ],
#             [
#                 0.12156862745098039,
#                 "rgba(38, 71, 172, 1.000)"
#             ],
#             [
#                 0.12549019607843137,
#                 "rgba(37, 72, 176, 1.000)"
#             ],
#             [
#                 0.12941176470588237,
#                 "rgba(35, 74, 179, 1.000)"
#             ],
#             [
#                 0.13333333333333333,
#                 "rgba(33, 76, 182, 1.000)"
#             ],
#             [
#                 0.13725490196078433,
#                 "rgba(31, 78, 184, 1.000)"
#             ],
#             [
#                 0.1411764705882353,
#                 "rgba(28, 80, 186, 1.000)"
#             ],
#             [
#                 0.1450980392156863,
#                 "rgba(25, 82, 188, 1.000)"
#             ],
#             [
#                 0.14901960784313725,
#                 "rgba(22, 85, 189, 1.000)"
#             ],
#             [
#                 0.15294117647058825,
#                 "rgba(19, 87, 190, 1.000)"
#             ],
#             [
#                 0.1568627450980392,
#                 "rgba(16, 89, 190, 1.000)"
#             ],
#             [
#                 0.1607843137254902,
#                 "rgba(13, 91, 190, 1.000)"
#             ],
#             [
#                 0.16470588235294117,
#                 "rgba(12, 94, 190, 1.000)"
#             ],
#             [
#                 0.16862745098039217,
#                 "rgba(10, 96, 190, 1.000)"
#             ],
#             [
#                 0.17254901960784313,
#                 "rgba(10, 98, 190, 1.000)"
#             ],
#             [
#                 0.17647058823529413,
#                 "rgba(10, 100, 190, 1.000)"
#             ],
#             [
#                 0.1803921568627451,
#                 "rgba(11, 102, 189, 1.000)"
#             ],
#             [
#                 0.1843137254901961,
#                 "rgba(13, 104, 189, 1.000)"
#             ],
#             [
#                 0.18823529411764706,
#                 "rgba(15, 106, 189, 1.000)"
#             ],
#             [
#                 0.19215686274509805,
#                 "rgba(17, 108, 188, 1.000)"
#             ],
#             [
#                 0.19607843137254902,
#                 "rgba(19, 110, 188, 1.000)"
#             ],
#             [
#                 0.2,
#                 "rgba(22, 112, 188, 1.000)"
#             ],
#             [
#                 0.20392156862745098,
#                 "rgba(25, 114, 187, 1.000)"
#             ],
#             [
#                 0.20784313725490197,
#                 "rgba(27, 116, 187, 1.000)"
#             ],
#             [
#                 0.21176470588235294,
#                 "rgba(30, 118, 187, 1.000)"
#             ],
#             [
#                 0.21568627450980393,
#                 "rgba(33, 120, 187, 1.000)"
#             ],
#             [
#                 0.2196078431372549,
#                 "rgba(35, 122, 186, 1.000)"
#             ],
#             [
#                 0.2235294117647059,
#                 "rgba(38, 123, 186, 1.000)"
#             ],
#             [
#                 0.22745098039215686,
#                 "rgba(41, 125, 186, 1.000)"
#             ],
#             [
#                 0.23137254901960785,
#                 "rgba(43, 127, 186, 1.000)"
#             ],
#             [
#                 0.23529411764705882,
#                 "rgba(46, 129, 186, 1.000)"
#             ],
#             [
#                 0.23921568627450981,
#                 "rgba(48, 131, 186, 1.000)"
#             ],
#             [
#                 0.24313725490196078,
#                 "rgba(51, 132, 186, 1.000)"
#             ],
#             [
#                 0.24705882352941178,
#                 "rgba(54, 134, 186, 1.000)"
#             ],
#             [
#                 0.25098039215686274,
#                 "rgba(56, 136, 186, 1.000)"
#             ],
#             [
#                 0.2549019607843137,
#                 "rgba(59, 137, 186, 1.000)"
#             ],
#             [
#                 0.25882352941176473,
#                 "rgba(62, 139, 186, 1.000)"
#             ],
#             [
#                 0.2627450980392157,
#                 "rgba(64, 141, 186, 1.000)

# %%
# Create an ngpkf grid based on the data
λₓ_wrong = 1/(4.0) 

σ_spatial = σ_sq
l_spatial = 1/λₓ_wrong

res_factor = 0.4 #l_spatial / sqrt(2.0)

kern = NGPKF.MaternKernel(σ_spatial, l_spatial)

ngp_grid_x = range(extrema(env_data.X)..., step= res_factor )
ngp_grid_y = range(extrema(env_data.Y)..., step= res_factor )



# ngp_grid_x = range(extrema(env_data.X)..., length=10) # step= res_factor )
# ngp_grid_y = range(extrema(env_data.Y)..., length=10)# step= res_factor )
# Out:
# 0.0:0.4:10.0

# %%
ngpkf_grid = NGPKF.NGPKFGrid(ngp_grid_x, ngp_grid_y, kern)
# Out:
# Main.NGPKF.NGPKFGrid{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{SVector{2, Float64}}, Hermitian{Float64, Matrix{Float64}}, Main.NGPKF.MaternKernel{Float64}}(0.0:0.4:24.8, 0.0:0.4:10.0, SVector{2, Float64}[[0.0, 0.0], [0.4, 0.0], [0.8, 0.0], [1.2, 0.0], [1.6, 0.0], [2.0, 0.0], [2.4, 0.0], [2.8, 0.0], [3.2, 0.0], [3.6, 0.0]  …  [21.2, 10.0], [21.6, 10.0], [22.0, 10.0], [22.4, 10.0], [22.8, 10.0], [23.2, 10.0], [23.6, 10.0], [24.0, 10.0], [24.4, 10.0], [24.8, 10.0]], Main.NGPKF.MaternKernel{Float64}(1.0, 4.0), [8.238163306308481 -4.280116567977607 … 1.5835949649823457e-7 5.120424345825411e-7; -4.280116567977607 11.276326456728125 … 3.895743207217191e-8 1.583594965098364e-7; … ; 1.5835949649823457e-7 3.895743207217191e-8 … 11.276326456728185 -4.280116567977641; 5.120424345825411e-7 1.583594965098364e-7 … -4.280116567977641 8.238163306308499])

# %%
size(ngp_grid_x), size(ngp_grid_y)
# Out:
# ((63,), (26,))

# %%
@assert maximum(abs.(ngpkf_grid.invK)) < 10.0
# Out:
# AssertionError: maximum(abs.(ngpkf_grid.invK)) < 10.0
#
# Stacktrace:
#  [1] top-level scope
#    @ In[10]:1

# %%
maximum(abs.(ngpkf_grid.invK))
# Out:
# 12.993280567376583

# %%
size(ngpkf_grid.invK')
# Out:
# (1638, 1638)

# %%
x0s = [@SVector[rand(ngpkf_grid.xs[2:(end-2)]), rand(ngpkf_grid.ys[2:(end-2)])] for i=1:1]
# Out:
# 1-element Vector{SVector{2, Float64}}:
#  [6.8, 7.6]

# %%
SimulatorSpatial.measure(0.0, x0s, env_data; σ_meas = 0.05)
# Out:
# 1-element Vector{Main.SimulatorTemp.MeasurementSpatial{Float64, SVector{2, Float64}, Float64}}:
#  Main.SimulatorTemp.MeasurementSpatial{Float64, SVector{2, Float64}, Float64}(0.0, [6.8, 7.6], 0.3625204720499103)

# %%
plot()
heatmap(env_data.X, env_data.Y, env_data.W', cmap = :balance; plottype=:wx)
scatter!(first.(x0s), last.(x0s))
plot!(clims=(-2,2))
# Out:
#     <div id="7f26bf90-4b12-4c40-8889-b160996db6f3" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['plotly'], function (Plotly) {
#
#     Plotly.newPlot('7f26bf90-4b12-4c40-8889-b160996db6f3', [
#     {
#         "showlegend": false,
#         "xaxis": "x",
#         "colorbar": {
#             "y": 0.513888888888889,
#             "title": "",
#             "len": 0.9525371828521435,
#             "x": 0.7615339749198018
#         },
#         "name": "y1",
#         "plottype": "wx",
#         "colorscale": [
#             [
#                 0.0,
#                 "rgba(24, 28, 67, 1.000)"
#             ],
#             [
#                 0.00392156862745098,
#                 "rgba(25, 30, 70, 1.000)"
#             ],
#             [
#                 0.00784313725490196,
#                 "rgba(26, 31, 73, 1.000)"
#             ],
#             [
#                 0.011764705882352941,
#                 "rgba(27, 33, 76, 1.000)"
#             ],
#             [
#                 0.01568627450980392,
#                 "rgba(28, 34, 79, 1.000)"
#             ],
#             [
#                 0.0196078431372549,
#                 "rgba(29, 35, 82, 1.000)"
#             ],
#             [
#                 0.023529411764705882,
#                 "rgba(30, 37, 85, 1.000)"
#             ],
#             [
#                 0.027450980392156862,
#                 "rgba(31, 38, 88, 1.000)"
#             ],
#             [
#                 0.03137254901960784,
#                 "rgba(32, 39, 91, 1.000)"
#             ],
#             [
#                 0.03529411764705882,
#                 "rgba(33, 41, 95, 1.000)"
#             ],
#             [
#                 0.0392156862745098,
#                 "rgba(33, 42, 98, 1.000)"
#             ],
#             [
#                 0.043137254901960784,
#                 "rgba(34, 43, 101, 1.000)"
#             ],
#             [
#                 0.047058823529411764,
#                 "rgba(35, 45, 105, 1.000)"
#             ],
#             [
#                 0.050980392156862744,
#                 "rgba(36, 46, 108, 1.000)"
#             ],
#             [
#                 0.054901960784313725,
#                 "rgba(37, 47, 111, 1.000)"
#             ],
#             [
#                 0.058823529411764705,
#                 "rgba(37, 48, 115, 1.000)"
#             ],
#             [
#                 0.06274509803921569,
#                 "rgba(38, 50, 118, 1.000)"
#             ],
#             [
#                 0.06666666666666667,
#                 "rgba(39, 51, 122, 1.000)"
#             ],
#             [
#                 0.07058823529411765,
#                 "rgba(39, 52, 125, 1.000)"
#             ],
#             [
#                 0.07450980392156863,
#                 "rgba(40, 54, 129, 1.000)"
#             ],
#             [
#                 0.0784313725490196,
#                 "rgba(40, 55, 132, 1.000)"
#             ],
#             [
#                 0.08235294117647059,
#                 "rgba(41, 56, 136, 1.000)"
#             ],
#             [
#                 0.08627450980392157,
#                 "rgba(41, 58, 140, 1.000)"
#             ],
#             [
#                 0.09019607843137255,
#                 "rgba(41, 59, 143, 1.000)"
#             ],
#             [
#                 0.09411764705882353,
#                 "rgba(41, 60, 147, 1.000)"
#             ],
#             [
#                 0.09803921568627451,
#                 "rgba(41, 62, 151, 1.000)"
#             ],
#             [
#                 0.10196078431372549,
#                 "rgba(41, 63, 154, 1.000)"
#             ],
#             [
#                 0.10588235294117647,
#                 "rgba(41, 64, 158, 1.000)"
#             ],
#             [
#                 0.10980392156862745,
#                 "rgba(41, 66, 162, 1.000)"
#             ],
#             [
#                 0.11372549019607843,
#                 "rgba(40, 67, 165, 1.000)"
#             ],
#             [
#                 0.11764705882352941,
#                 "rgba(39, 69, 169, 1.000)"
#             ],
#             [
#                 0.12156862745098039,
#                 "rgba(38, 71, 172, 1.000)"
#             ],
#             [
#                 0.12549019607843137,
#                 "rgba(37, 72, 176, 1.000)"
#             ],
#             [
#                 0.12941176470588237,
#                 "rgba(35, 74, 179, 1.000)"
#             ],
#             [
#                 0.13333333333333333,
#                 "rgba(33, 76, 182, 1.000)"
#             ],
#             [
#                 0.13725490196078433,
#                 "rgba(31, 78, 184, 1.000)"
#             ],
#             [
#                 0.1411764705882353,
#                 "rgba(28, 80, 186, 1.000)"
#             ],
#             [
#                 0.1450980392156863,
#                 "rgba(25, 82, 188, 1.000)"
#             ],
#             [
#                 0.14901960784313725,
#                 "rgba(22, 85, 189, 1.000)"
#             ],
#             [
#                 0.15294117647058825,
#                 "rgba(19, 87, 190, 1.000)"
#             ],
#             [
#                 0.1568627450980392,
#                 "rgba(16, 89, 190, 1.000)"
#             ],
#             [
#                 0.1607843137254902,
#                 "rgba(13, 91, 190, 1.000)"
#             ],
#             [
#                 0.16470588235294117,
#                 "rgba(12, 94, 190, 1.000)"
#             ],
#             [
#                 0.16862745098039217,
#                 "rgba(10, 96, 190, 1.000)"
#             ],
#             [
#                 0.17254901960784313,
#                 "rgba(10, 98, 190, 1.000)"
#             ],
#             [
#                 0.17647058823529413,
#                 "rgba(10, 100, 190, 1.000)"
#             ],
#             [
#                 0.1803921568627451,
#                 "rgba(11, 102, 189, 1.000)"
#             ],
#             [
#                 0.1843137254901961,
#                 "rgba(13, 104, 189, 1.000)"
#             ],
#             [
#                 0.18823529411764706,
#                 "rgba(15, 106, 189, 1.000)"
#             ],
#             [
#                 0.19215686274509805,
#                 "rgba(17, 108, 188, 1.000)"
#             ],
#             [
#                 0.19607843137254902,
#                 "rgba(19, 110, 188, 1.000)"
#             ],
#             [
#                 0.2,
#                 "rgba(22, 112, 188, 1.000)"
#             ],
#             [
#                 0.20392156862745098,
#                 "rgba(25, 114, 187, 1.000)"
#             ],
#             [
#                 0.20784313725490197,
#                 "rgba(27, 116, 187, 1.000)"
#             ],
#             [
#                 0.21176470588235294,
#                 "rgba(30, 118, 187, 1.000)"
#             ],
#             [
#                 0.21568627450980393,
#                 "rgba(33, 120, 187, 1.000)"
#             ],
#             [
#                 0.2196078431372549,
#                 "rgba(35, 122, 186, 1.000)"
#             ],
#             [
#                 0.2235294117647059,
#                 "rgba(38, 123, 186, 1.000)"
#             ],
#             [
#                 0.22745098039215686,
#                 "rgba(41, 125, 186, 1.000)"
#             ],
#             [
#                 0.23137254901960785,
#                 "rgba(43, 127, 186, 1.000)"
#             ],
#             [
#                 0.23529411764705882,
#                 "rgba(46, 129, 186, 1.000)"
#             ],
#             [
#                 0.23921568627450981,
#                 "rgba(48, 131, 186, 1.000)"
#             ],
#             [
#                 0.24313725490196078,
#                 "rgba(51, 132, 186, 1.000)"
#             ],
#             [
#                 0.24705882352941178,
#                 "rgba(54, 134, 186, 1.000)"
#             ],
#             [
#                 0.25098039215686274,
#                 "rgba(56, 136, 186, 1.000)"
#             ],
#             [
#                 0.2549019607843137,
#                 "rgba(59, 137, 186, 1.000)"
#             ],
#             [
#                 0.25882352941176473,
#                 "rgba(62, 139, 186, 1.000)"
#             ],
#             [
#                 0.2627450980392157,
#                 "rgba(64, 141, 186, 1.000)

# %%
ΔT = 5.0 / 60.0 # seconds
Tend = 1.0 # hours 
ts = 0.0:(ΔT):(Tend * 60)
# Out:
# 0.0:0.08333333333333333:60.0

# %%
function Cfun(p, x)
    return kern(x, p)^2 / kern(p, p)
end
function Rfun(p, x)
    return (kern(x,x) - kern(x, p)^2 / kern(p, p) + 0.5^2)/(ΔT)
end


S(p, x)  = Cfun(p, x)^2 / Rfun(p, x)
DxS(p, x) = ForwardDiff.gradient(xx-> S(p, xx), x)
# Out:
# DxS (generic function with 1 method)

# %%
using DifferentialEquations
using ForwardDiff

function clarity_prediction(t, q0, C, R, Q)

    k = C / sqrt(Q * R)
    
    q∞ = k / (1 + k)

    γ1 = q∞ - q0
    γ2 = γ1 * (k-1)
    γ3 = (k-1) * q0 - k

    return q∞ * ( 1 + 2 * γ1 / (γ2 + γ3 * exp(2 * k * Q * t)))
end

    
function clarity_time(q0, qf, C, R, Q; tmax=10.0)
    
    println("q0: $(q0)")
    println("qf: $(qf)")
    println("C: $(C)")
    println("R: $(R)")
    println("Q: $(Q)")
    
    if q0 >= qf
        return 0.0
    end

    k = C / sqrt(Q * R)
    println("k: $(k)")
    
    q∞ = k / (1 + k)
    println("q∞: $(q∞)")
    γ1 = q∞ - q0
    γ2 = γ1 * (k-1)
    γ3 = (k-1) * q0 - k

    
        
    if qf >= q∞
        return tmax
    end

    t = log((2*q∞*γ1 - qf*γ2 + q∞*γ2)/((qf - q∞)*γ3))/(2*k*Q)
    println("t: $(t)")

    return min(t, tmax)
end

C = 1.0
R = 0.5
Q = 0.0
Clarity_decay(u,p,t) = (C^2 / R) * (1-u)^2 - Q * u^2


function Forward_Simulate_Clarity(current_clarity, target_clarity; fn::Function = Clarity)
    """
    Forward simulate for maximum 10 seconds
    Here for now I only consider the spatiostatic environment 
    """    
    tspan = (0.0, 10.0) # 10 is just chosen to be a huge value for this problem
    u0 = current_clarity
    prob = ODEProblem(fn, u0, tspan)
    condition(u, t, integrator) = u ≥ target_clarity
    affect!(integrator) = terminate!(integrator)
    cb = DiscreteCallback(condition, affect!)
    sol = solve(prob, Tsit5(), callback = cb);
    return sol.t[end]
    
end
# Out:
# Forward_Simulate_Clarity (generic function with 1 method)

# %%
# Qp  = mean(σ_t.^2) # diagm(vec(σ_t .^2 * fuse_measurements_every_ΔT ))

# %%
 δt = Forward_Simulate_Clarity(0.5, 0.9; fn = Clarity_decay)
# Out:
# 4.941428437228555

# %%
using LinearAlgebra, StatsBase

function ergo_controller3(t, xs; 
        ergo_grid,
        ergo_q_map,
        traj,
        umax=30.0 * 60 / 1000,
        ΔT,
        kwargs...
        )

    target_q = 0.8 ; # * ones(size(ergo_q_map))

    target_spatial_dist = zeros(size(ergo_q_map))

    Qp  = mean(σ_t.^2) # diagm(vec(σ_t .^2 * fuse_measurements_every_ΔT ))

    C_ = Cfun(0,0)
    R_ = Rfun(0,0)
    
#     println("ergo_q_map: $(ergo_q_map)")
    
    for i in CartesianIndices(target_spatial_dist)
        if target_q > ergo_q_map[i]
            target_spatial_dist[i] = Forward_Simulate_Clarity(ergo_q_map[i], target_q; fn = Clarity_decay)
        else
            target_spatial_dist[i] = 0.0
        end
#         target_spatial_dist[i] = clarity_time(ergo_q_map[i], target_q, C_, R_, Qp)
        

    end
    
#     println("target_spatial_dist: $(target_spatial_dist)")
    # Remove Nans
    
#     for cell in CartesianIndices(target_spatial_dist)
#         if isnan(target_spatial_dist[cell])
#             target_spatial_dist[cell] = 0
#         else 
#             target_spatial_dist[cell] = max(0, target_spatial_dist[cell])
#         end
#     end
        
    u = [ErgodicController.controller_single_integrator(ergo_grid, x, traj, target_spatial_dist; umax=umax) for x in xs]
    return u

end

ergo_controllers3 = [ergo_controller3 for i=1:length(x0s)]
# Out:
# 1-element Vector{typeof(ergo_controller3)}:
#  ergo_controller3 (generic function with 1 method)

# %%
ΔT = 5.0/60.0 # minutes
Tend = 0.1 # hours 
ts = 0.0:(ΔT):(110)
fuse_measurements_every_ΔT = 5.0 # minutes
recompute_controller_every_ΔT = 5.0 / 60.0 # minutes
σ_t = zeros(63, 26);

# %%
5.0/60.0
# Out:
# 0.08333333333333333

# %%
@time res_ergo =  SimulatorSpatial.simulate_spatial(ts, x0s, ergo_controller3; 
    ngpkf_grid=ngpkf_grid, 
    EnvDataSpatial=env_data, 
    σ_meas = 0.5,
    # σ_process= 0.075 * fuse_measurements_every_ΔT,
    Q_process = diagm(vec(σ_t .^2 * fuse_measurements_every_ΔT )) , 
    fuse_measurements_every_ΔT = fuse_measurements_every_ΔT, 
    recompute_controller_every_ΔT = recompute_controller_every_ΔT)
# Out:
# Progress:   0%|                                         |  ETA: N/A
# Progress:   1%|▎                                        |  ETA: 0:27:18
# Progress:   1%|▍                                        |  ETA: 0:26:05
# Progress:   2%|▋                                        |  ETA: 0:25:43
# Progress:   2%|▉                                        |  ETA: 0:25:31
# Progress:   3%|█▏                                       |  ETA: 0:25:27
# Progress:   3%|█▎                                       |  ETA: 0:25:20
# Progress:   4%|█▌                                       |  ETA: 0:25:10
# Progress:   4%|█▊                                       |  ETA: 0:24:59
# Inside prediction of NGP
# Progress:   5%|██                                       |  ETA: 0:24:42
# Progress:   5%|██▏                                      |  ETA: 0:24:06
# Progress:   6%|██▍                                      |  ETA: 0:23:37
# Progress:   6%|██▋                                      |  ETA: 0:23:13
# Progress:   7%|██▉                                      |  ETA: 0:22:50
# Progress:   7%|███                                      |  ETA: 0:22:31
# Progress:   8%|███▎                                     |  ETA: 0:22:11
# Progress:   8%|███▌                                     |  ETA: 0:21:55
# Progress:   9%|███▊                                     |  ETA: 0:21:39
# Inside prediction of NGP
# Progress:  10%|███▉                                     |  ETA: 0:21:15
# Progress:  10%|████▏                                    |  ETA: 0:20:48
# Progress:  11%|████▍                                    |  ETA: 0:20:25
# Progress:  11%|████▋                                    |  ETA: 0:20:03
# Progress:  12%|████▊                                    |  ETA: 0:19:42
# Progress:  12%|█████                                    |  ETA: 0:19:23
# Progress:  13%|█████▎                                   |  ETA: 0:19:05
# Progress:  13%|█████▍                                   |  ETA: 0:18:48
# Inside prediction of NGP
# Progress:  14%|█████▋                                   |  ETA: 0:18:34
# Progress:  14%|█████▉                                   |  ETA: 0:18:12
# Progress:  15%|██████▏                                  |  ETA: 0:17:51
# Progress:  15%|██████▎                                  |  ETA: 0:17:32
# Progress:  16%|██████▌                                  |  ETA: 0:17:13
# Progress:  16%|██████▊                                  |  ETA: 0:16:56
# Progress:  17%|███████                                  |  ETA: 0:16:40
# Progress:  18%|███████▏                                 |  ETA: 0:16:24
# Progress:  18%|███████▍                                 |  ETA: 0:16:08
# Inside prediction of NGP
# Progress:  19%|███████▋                                 |  ETA: 0:15:53
# Progress:  19%|███████▉                                 |  ETA: 0:15:36
# Progress:  20%|████████                                 |  ETA: 0:15:20
# Progress:  20%|████████▎                                |  ETA: 0:15:04
# Progress:  21%|████████▌                                |  ETA: 0:14:49
# Progress:  21%|████████▊                                |  ETA: 0:14:35
# Progress:  22%|████████▉                                |  ETA: 0:14:21
# Progress:  22%|█████████▏                               |  ETA: 0:14:07
# Inside prediction of NGP
# Progress:  23%|█████████▍                               |  ETA: 0:13:56
# Progress:  23%|█████████▋                               |  ETA: 0:13:43
# Progress:  24%|█████████▊                               |  ETA: 0:13:30
# Progress:  24%|██████████                               |  ETA: 0:13:18
# Progress:  25%|██████████▎                              |  ETA: 0:13:07
# Progress:  25%|██████████▍                              |  ETA: 0:12:55
# Progress:  26%|██████████▋                              |  ETA: 0:12:44
# Progress:  27%|██████████▉                              |  ETA: 0:12:34
# Progress:  27%|███████████▏                             |  ETA: 0:12:23
# Inside prediction of NGP
# Progress:  28%|███████████▎                             |  ETA: 0:12:12
# Progress:  28%|███████████▌                             |  ETA: 0:11:59
# Progress:  29%|███████████▊                             |  ETA: 0:11:46
# Progress:  29%|████████████                             |  ETA: 0:11:33
# Progress:  30%|████████████▏                            |  ETA: 0:11:21
# Progress:  30%|████████████▍                            |  ETA: 0:11:09
# Progress:  31%|████████████▋                            |  ETA: 0:10:58
# Progress:  31%|████████████▉                            |  ETA: 0:10:47
# Inside prediction of NGP
# Progress:  32%|█████████████                            |  ETA: 0:10:36
# Progress:  32%|█████████████▎                           |  ETA: 0:10:26
# Progress:  33%|█████████████▌                           |  ETA: 0:10:15
# Progress:  33%|█████████████▊                           |  ETA: 0:10:04
# Progress:  34%|█████████████▉                           |  ETA: 0:09:53
# Progress:  34%|██████████████▏                          |  ETA: 0:09:43
# Progress:  35%|██████████████▍                          |  ETA: 0:09:33
# Progress:  36%|██████████████▋                          |  ETA: 0:09:23
# Progress:  36%|██████████████▊                          |  ETA: 0:09:14
# Inside prediction of NGP
# Progress:  37%|███████████████                          |  ETA: 0:09:05
# Progress:  37%|███████████████▎                         |  ETA: 0:08:55
# Progress:  38%|███████████████▍                         |  ETA: 0:08:46
# Progress:  38%|███████████████▋                         |  ETA: 0:08:36
# Progress:  39%|███████████████▉                         |  ETA: 0:08:27
# Progress:  39%|████████████████▏                        |  ETA: 0:08:18
# Progress:  40%|████████████████▎                        |  ETA: 0:08:10
# Progress:  40%|████████████████▌                        |  ETA: 0:08:01
# Progress:  41%|████████████████▊                        |  ETA: 0:07:53
# Inside prediction of NGP
# Progress:  41%|█████████████████                        |  ETA: 0:07:45
# Progress:  42%|█████████████████▏                       |  ETA: 0:07:37
# Progress:  42%|█████████████████▍                       |  ETA: 0:07:28
# Progress:  43%|█████████████████▋                       |  ETA: 0:07:20
# Progress:  43%|█████████████████▉                       |  ETA: 0:07:11
# Progress:  44%|██████████████████                       |  ETA: 0:07:03
# Progress:  45%|██████████████████▎                      |  ETA: 0:06:56
# Progress:  45%|██████████████████▌                      |  ETA: 0:06:48
# Inside prediction of NGP
# Progress:  46%|██████████████████▊                      |  ETA: 0:06:41
# Progress:  46%|██████████████████▉                      |  ETA: 0:06:33
# Progress:  47%|███████████████████▏                     |  ETA: 0:06:26
# Progress:  47%|███████████████████▍                     |  ETA: 0:06:18
# Progress:  48%|███████████████████▋                     |  ETA: 0:06:11
# Progress:  48%|███████████████████▊                     |  ETA: 0:06:04
# Progress:  49%|████████████████████                     |  ETA: 0:05:58
# Progress:  49%|████████████████████▎                    |  ETA: 0:05:51
# Progress:  50%|████████████████████▌                    |  ETA: 0:05:44
# Inside prediction of NGP
# Progress:  50%|████████████████████▋                    |  ETA: 0:05:38
# Progress:  51%|████████████████████▉                    |  ETA: 0:05:32
# Progress:  51%|█████████████████████▏                   |  ETA: 0:05:25
# Progress:  52%|█████████████████████▎                   |  ETA: 0:05:19
# Progress:  52%|█████████████████████▌                   |  ETA: 0:05:13
# Progress:  53%|█████████████████████▊                   |  ETA: 0:05:07
# Progress:  54%|██████████████████████                   |  ETA: 0:05:01
# Progress:  54%|██████████████████████▏                  |  ETA: 0:04:55
# Inside prediction of NGP
# Progress:  55%|██████████████████████▍                  |  ETA: 0:04:50
# Progress:  55%|██████████████████████▋                  |  ETA: 0:04:44
# Progress:  56%|██████████████████████▉                  |  ETA: 0:04:39
# Progress:  56%|███████████████████████                  |  ETA: 0:04:33
# Progress:  57%|███████████████████████▎                 |  ETA: 0:04:28
# Progress:  57%|███████████████████████▌                 |  ETA: 0:04:23
# Progress:  58%|███████████████████████▊                 |  ETA: 0:04:18
# Progress:  58%|███████████████████████▉                 |  ETA: 0:04:13
# Progress:  59%|████████████████████████▏                |  ETA: 0:04:07
# Inside prediction of NGP
# Progress:  59%|████████████████████████▍                |  ETA: 0:04:03
# Progress:  60%|████████████████████████▋                |  ETA: 0:03:58
# Progress:  60%|████████████████████████▊                |  ETA: 0:03:53
# Progress:  61%|█████████████████████████                |  ETA: 0:03:48
# Progress:  62%|█████████████████████████▎               |  ETA: 0:03:43
# Progress:  62%|█████████████████████████▌               |  ETA: 0:03:38
# Progress:  63%|█████████████████████████▋               |  ETA: 0:03:33
# Progress:  63%|█████████████████████████▉               |  ETA: 0:03:29
# Inside prediction of NGP
# Progress:  64%|██████████████████████████▏              |  ETA: 0:03:24
# Progress:  64%|██████████████████████████▎              |  ETA: 0:03:20
# Progress:  65%|██████████████████████████▌              |  ETA: 0:03:15
# Progress:  65%|██████████████████████████▊              |  ETA: 0:03:11
# Progress:  66%|███████████████████████████              |  ETA: 0:03:07
# Progress:  66%|███████████████████████████▏             |  ETA: 0:03:03
# Progress:  67%|███████████████████████████▍             |  ETA: 0:02:58
# Progress:  67%|███████████████████████████▋             |  ETA: 0:02:54
# Progress:  68%|███████████████████████████▉             |  ETA: 0:02:50
# Inside prediction of NGP
# Progress:  68%|████████████████████████████             |  ETA: 0:02:46
# Progress:  69%|████████████████████████████▎            |  ETA: 0:02:42
# Progress:  69%|████████████████████████████▌            |  ETA: 0:02:39
# Progress:  70%|████████████████████████████▊            |  ETA: 0:02:35
# Progress:  71%|████████████████████████████▉            |  ETA: 0:02:31
# Progress:  71%|█████████████████████████████▏           |  ETA: 0:02:27
# Progress:  72%|█████████████████████████████▍           |  ETA: 0:02:23
# Progress:  72%|█████████████████████████████▋           |  ETA: 0:02:20
# Inside prediction of NGP
# Progress:  73%|█████████████████████████████▊           |  ETA: 0:02:16
# Progress:  73%|██████████████████████████████           |  ETA: 0:02:13
# Progress:  74%|██████████████████████████████▎          |  ETA: 0:02:09
# Progress:  74%|██████████████████████████████▌          |  ETA: 0:02:06
# Progress:  75%|██████████████████████████████▋          |  ETA: 0:02:03
# Progress:  75%|██████████████████████████████▉          |  ETA: 0:01:59
# Progress:  76%|███████████████████████████████▏         |  ETA: 0:01:56
# Progress:  76%|███████████████████████████████▎         |  ETA: 0:01:53
# Progress:  77%|███████████████████████████████▌         |  ETA: 0:01:49
# Inside prediction of NGP
# Progress:  77%|███████████████████████████████▊         |  ETA: 0:01:46
# Progress:  78%|████████████████████████████████         |  ETA: 0:01:43
# Progress:  78%|████████████████████████████████▏        |  ETA: 0:01:40
# Progress:  79%|████████████████████████████████▍        |  ETA: 0:01:37
# Progress:  80%|████████████████████████████████▋        |  ETA: 0:01:34
# Progress:  80%|████████████████████████████████▉        |  ETA: 0:01:31
# Progress:  81%|█████████████████████████████████        |  ETA: 0:01:28
# Progress:  81%|█████████████████████████████████▎       |  ETA: 0:01:25
# Inside prediction of NGP
# Progress:  82%|█████████████████████████████████▌       |  ETA: 0:01:22
# Progress:  82%|█████████████████████████████████▊       |  ETA: 0:01:19
# Progress:  83%|█████████████████████████████████▉       |  ETA: 0:01:16
# Progress:  83%|██████████████████████████████████▏      |  ETA: 0:01:14
# Progress:  84%|██████████████████████████████████▍      |  ETA: 0:01:11
# Progress:  84%|██████████████████████████████████▋      |  ETA: 0:01:08
# Progress:  85%|██████████████████████████████████▊      |  ETA: 0:01:05
# Progress:  85%|███████████████████████████████████      |  ETA: 0:01:03
# Progress:  86%|███████████████████████████████████▎     |  ETA: 0:01:00
# Inside prediction of NGP
# Progress:  86%|███████████████████████████████████▌     |  ETA: 0:00:58
# Progress:  87%|███████████████████████████████████▋     |  ETA: 0:00:55
# Progress:  88%|███████████████████████████████████▉     |  ETA: 0:00:52
# Progress:  88%|████████████████████████████████████▏    |  ETA: 0:00:50
# Progress:  89%|████████████████████████████████████▎    |  ETA: 0:00:47
# Progress:  89%|████████████████████████████████████▌    |  ETA: 0:00:45
# Progress:  90%|████████████████████████████████████▊    |  ETA: 0:00:42
# Progress:  90%|█████████████████████████████████████    |  ETA: 0:00:40
# Inside prediction of NGP
# Progress:  91%|█████████████████████████████████████▏   |  ETA: 0:00:38
# Progress:  91%|█████████████████████████████████████▍   |  ETA: 0:00:35
# Progress:  92%|█████████████████████████████████████▋   |  ETA: 0:00:33
# Progress:  92%|█████████████████████████████████████▉   |  ETA: 0:00:31
# Progress:  93%|██████████████████████████████████████   |  ETA: 0:00:29
# Progress:  93%|██████████████████████████████████████▎  |  ETA: 0:00:26
# Progress:  94%|██████████████████████████████████████▌  |  ETA: 0:00:24
# Progress:  94%|██████████████████████████████████████▊  |  ETA: 0:00:22
# Inside prediction of NGP
# Progress:  95%|██████████████████████████████████████▉  |  ETA: 0:00:20
# Progress:  95%|███████████████████████████████████████▏ |  ETA: 0:00:18
# Progress:  96%|███████████████████████████████████████▍ |  ETA: 0:00:15
# Progress:  97%|███████████████████████████████████████▋ |  ETA: 0:00:13
# Progress:  97%|███████████████████████████████████████▊ |  ETA: 0:00:11
# Progress:  98%|████████████████████████████████████████ |  ETA: 0:00:09
# Progress:  98%|████████████████████████████████████████▎|  ETA: 0:00:07
# Progress:  99%|████████████████████████████████████████▌|  ETA: 0:00:05
# 370.431874 seconds (12.47 G allocations: 298.451 GiB, 5.04% gc time, 0.06% compilation time: 63% of which was recompilation)
# Progress:  99%|████████████████████████████████████████▋|  ETA: 0:00:03
# Progress: 100%|████████████████████████████████████████▉|  ETA: 0:00:01
# Progress: 100%|█████████████████████████████████████████| Time: 0:06:08
# Main.SimulatorTemp.SimResult{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Vector{SVector{2, Float64}}}, Vector{Vector{SVector{2, Float64}}}, Vector{Main.SimulatorTemp.MeasurementSpatial{Float64, SVector{2, Float64}, Float64}}, Vector{Float64}, Vector{Main.KF.KFState{Vector{Float64}, UpperTriangular{Float64, Matrix{Float64}}}}, Vector{Matrix{Float64}}}(0.0:0.08333333333333333:110.0, Vector{SVector{2, Float64}}[[[13.6, 4.4]], [[13.746223098223695, 4.433448550728898]], [[13.886326131247388, 4.487031571710938]], [[14.008418345573418, 4.574172212062996]], [[14.082733743599222, 4.704468879772751]], [[14.145746249164736, 4.8405917071837194]], [[14.199940531671675, 4.98045942949147]], [[14.23679648183276, 5.125861076448179]], [[14.268325916053142, 5.27250995908198]], [[14.30291835454194, 5.418466675951739]]  …  [[10.696687528768267, 3.7053198834980616]], [[10.70820421553027, 3.5557626505535267]], [[10.69690388438803, 3.70533638660393]], [[10.708864640040174, 3.5558140126118425]], [[10.697126596133373, 3.7053540350982725]], [[10.709519714753748, 3.555866876416126]], [[10.697355280851683, 3.70537281792964]], [[10.710169834001915, 3.5559211962336548]], [[10.6975898598206, 3.7053927462008556]], [[10.71081478484179, 3.5559768790441715]]], Vector{SVector{2, Float64}}[[[1.7546771786843396, 0.40138260874677445]], [[1.7546771786843396, 0.40138260874677445]], [[1.6812363962843293, 0.6429962517844733]], [[1.4651065719123575, 1.045687684224702]], [[0.8917847763096486, 1.5635600125170603]], [[0.7561500667861535, 1.6334739289316176]], [[0.6503313900832739, 1.6784126676930071]], [[0.44227140193301884, 1.7448197634805156]], [[0.37835321064458144, 1.759786591605623]], [[0.41510926186558583, 1.751480602437095]]  …  [[-0.1302249476910781, 1.7952831149985384]], [[0.1382002411440176, -1.7946867953344214]], [[-0.13560397370687402, 1.7948848326048403]], [[0.14352906782571545, -1.7942684879050521]], [[-0.1408565268816056, 1.7944802698371614]], [[0.1487174234445075, -1.7938459041857602]], [[-0.14597320682478138, 1.7940712981621687]], [[0.1537746378027789, -1.7934194603518232]], [[-0.1509596901757992, 1.7936585996064098]], [[0.15869910025429151, -1.7929904058802093]]], Main.SimulatorTemp.MeasurementSpatial{Float64, SVector{2, Float64}, Float64}[Main.SimulatorTemp.MeasurementSpatial{Float64, SVector{2, Float64}, Float64}(0.0, [13.6, 4.4], -1.222836452393651), Main.SimulatorTemp.MeasurementSpatial{Float64, SVector{2, Float64}, Float64}(0.0, [13.6, 4.4], -1.222836452393651), Main.SimulatorTemp.MeasurementSpatial{Float64, SVector{2, Float64}, Float64}(0.08333333333333333, [13.746223098223695, 4.433448550728898], -1.2290998217625566), Main.SimulatorTemp.MeasurementSpatial{Float64, SVector{2, Float64}, Float64}(0.16666666666666666, [13.886326131247388, 4.487031571710938], -0.9283006420084204), Main.SimulatorTemp.MeasurementSpatial{Float64, SVector{2, Float64}, Float64}(0.25, [14.008418345573418, 4.574172212062996], -0.5749858085309044), Main.SimulatorTemp.MeasurementSpatial{Float64, SVector{2, Float64}, Float64}(0.3333333333333333, [14.082733743599222, 4.704468879772751], -0.5399084689979147), Main.SimulatorTemp.MeasurementSpatial{Float64, SVector{2, Float64}, Float64}(0.4166666666666667, [14.145746249164736, 4.8405917071837194], -0.5315425414281386), Main.SimulatorTemp.MeasurementSpatial{Float64, SVector{2, Float64}, Float64}(0.5, [14.199940531671675, 4.98045942949147], -0.44851000554894993), Main.SimulatorTemp.MeasurementSpatial{Float64, SVector{2, Float64}, Float64}(0.5833333333333334, [14.23679648183276, 5.125861076448179], -0.5223505496592109), Main.SimulatorTemp.MeasurementSpatial{Float64, SVector{2, Float64}, Float64}(0.6666666666666666, [14.268325916053142, 5.27250995908198], -0.7211639045070146)  …  Main.SimulatorTemp.MeasurementSpatial{Float64, SVector{2, Float64}, Float64}(109.16666666666667, [10.707539607742524, 3.5557129572481836], 0.9915573789344381), Main.SimulatorTemp.MeasurementSpatial{Float64, SVe ...

# %%
typeof(x0s)
# Out:
# Vector{SVector{2, Float64}} (alias for Array{SArray{Tuple{2}, Float64, 1, 2}, 1})

# %%
x0s
# Out:
# 1-element Vector{SVector{2, Float64}}:
#  [13.6, 4.4]

# %%
res_ergo.xs
# Out:
# 1321-element Vector{Vector{SVector{2, Float64}}}:
#  [[13.6, 4.4]]
#  [[13.746223098223695, 4.433448550728898]]
#  [[13.886326131247388, 4.487031571710938]]
#  [[14.008418345573418, 4.574172212062996]]
#  [[14.082733743599222, 4.704468879772751]]
#  [[14.145746249164736, 4.8405917071837194]]
#  [[14.199940531671675, 4.98045942949147]]
#  [[14.23679648183276, 5.125861076448179]]
#  [[14.268325916053142, 5.27250995908198]]
#  [[14.30291835454194, 5.418466675951739]]
#  [[14.325702673408104, 5.56672616068646]]
#  [[14.343991351001732, 5.715607067023963]]
#  [[14.362866816902766, 5.864414717321314]]
#  ⋮
#  [[10.69647712741355, 3.7053044728129745]]
#  [[10.707539607742524, 3.5557129572481836]]
#  [[10.696687528768267, 3.7053198834980616]]
#  [[10.70820421553027, 3.5557626505535267]]
#  [[10.69690388438803, 3.70533638660393]]
#  [[10.708864640040174, 3.5558140126118425]]
#  [[10.697126596133373, 3.7053540350982725]]
#  [[10.709519714753748, 3.555866876416126]]
#  [[10.697355280851683, 3.70537281792964]]
#  [[10.710169834001915, 3.5559211962336548]]
#  [[10.6975898598206, 3.7053927462008556]]
#  [[10.71081478484179, 3.5559768790441715]]

# %%
length(x0s)
# Out:
# 1

# %%
plot()
heatmap(env_data.X, env_data.Y, env_data.W', cmap = :balance; plottype=:wx, clims=(-2, 2))
for i=1:length(x0s)
    x = [r[i][1] for r in res_ergo.xs]
    y = [r[i][2] for r in res_ergo.xs]
    plot!(x, y, linewidth=3, color=:black)
end
plot!()
# Out:
#     <div id="8f37f7bf-415c-4993-9da9-a61a886b93c8" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['plotly'], function (Plotly) {
#
#     Plotly.newPlot('8f37f7bf-415c-4993-9da9-a61a886b93c8', [
#     {
#         "showlegend": false,
#         "xaxis": "x",
#         "colorbar": {
#             "y": 0.513888888888889,
#             "title": "",
#             "len": 0.9525371828521435,
#             "x": 0.7615339749198018
#         },
#         "name": "y1",
#         "plottype": "wx",
#         "colorscale": [
#             [
#                 0.0,
#                 "rgba(24, 28, 67, 1.000)"
#             ],
#             [
#                 0.00392156862745098,
#                 "rgba(25, 30, 70, 1.000)"
#             ],
#             [
#                 0.00784313725490196,
#                 "rgba(26, 31, 73, 1.000)"
#             ],
#             [
#                 0.011764705882352941,
#                 "rgba(27, 33, 76, 1.000)"
#             ],
#             [
#                 0.01568627450980392,
#                 "rgba(28, 34, 79, 1.000)"
#             ],
#             [
#                 0.0196078431372549,
#                 "rgba(29, 35, 82, 1.000)"
#             ],
#             [
#                 0.023529411764705882,
#                 "rgba(30, 37, 85, 1.000)"
#             ],
#             [
#                 0.027450980392156862,
#                 "rgba(31, 38, 88, 1.000)"
#             ],
#             [
#                 0.03137254901960784,
#                 "rgba(32, 39, 91, 1.000)"
#             ],
#             [
#                 0.03529411764705882,
#                 "rgba(33, 41, 95, 1.000)"
#             ],
#             [
#                 0.0392156862745098,
#                 "rgba(33, 42, 98, 1.000)"
#             ],
#             [
#                 0.043137254901960784,
#                 "rgba(34, 43, 101, 1.000)"
#             ],
#             [
#                 0.047058823529411764,
#                 "rgba(35, 45, 105, 1.000)"
#             ],
#             [
#                 0.050980392156862744,
#                 "rgba(36, 46, 108, 1.000)"
#             ],
#             [
#                 0.054901960784313725,
#                 "rgba(37, 47, 111, 1.000)"
#             ],
#             [
#                 0.058823529411764705,
#                 "rgba(37, 48, 115, 1.000)"
#             ],
#             [
#                 0.06274509803921569,
#                 "rgba(38, 50, 118, 1.000)"
#             ],
#             [
#                 0.06666666666666667,
#                 "rgba(39, 51, 122, 1.000)"
#             ],
#             [
#                 0.07058823529411765,
#                 "rgba(39, 52, 125, 1.000)"
#             ],
#             [
#                 0.07450980392156863,
#                 "rgba(40, 54, 129, 1.000)"
#             ],
#             [
#                 0.0784313725490196,
#                 "rgba(40, 55, 132, 1.000)"
#             ],
#             [
#                 0.08235294117647059,
#                 "rgba(41, 56, 136, 1.000)"
#             ],
#             [
#                 0.08627450980392157,
#                 "rgba(41, 58, 140, 1.000)"
#             ],
#             [
#                 0.09019607843137255,
#                 "rgba(41, 59, 143, 1.000)"
#             ],
#             [
#                 0.09411764705882353,
#                 "rgba(41, 60, 147, 1.000)"
#             ],
#             [
#                 0.09803921568627451,
#                 "rgba(41, 62, 151, 1.000)"
#             ],
#             [
#                 0.10196078431372549,
#                 "rgba(41, 63, 154, 1.000)"
#             ],
#             [
#                 0.10588235294117647,
#                 "rgba(41, 64, 158, 1.000)"
#             ],
#             [
#                 0.10980392156862745,
#                 "rgba(41, 66, 162, 1.000)"
#             ],
#             [
#                 0.11372549019607843,
#                 "rgba(40, 67, 165, 1.000)"
#             ],
#             [
#                 0.11764705882352941,
#                 "rgba(39, 69, 169, 1.000)"
#             ],
#             [
#                 0.12156862745098039,
#                 "rgba(38, 71, 172, 1.000)"
#             ],
#             [
#                 0.12549019607843137,
#                 "rgba(37, 72, 176, 1.000)"
#             ],
#             [
#                 0.12941176470588237,
#                 "rgba(35, 74, 179, 1.000)"
#             ],
#             [
#                 0.13333333333333333,
#                 "rgba(33, 76, 182, 1.000)"
#             ],
#             [
#                 0.13725490196078433,
#                 "rgba(31, 78, 184, 1.000)"
#             ],
#             [
#                 0.1411764705882353,
#                 "rgba(28, 80, 186, 1.000)"
#             ],
#             [
#                 0.1450980392156863,
#                 "rgba(25, 82, 188, 1.000)"
#             ],
#             [
#                 0.14901960784313725,
#                 "rgba(22, 85, 189, 1.000)"
#             ],
#             [
#                 0.15294117647058825,
#                 "rgba(19, 87, 190, 1.000)"
#             ],
#             [
#                 0.1568627450980392,
#                 "rgba(16, 89, 190, 1.000)"
#             ],
#             [
#                 0.1607843137254902,
#                 "rgba(13, 91, 190, 1.000)"
#             ],
#             [
#                 0.16470588235294117,
#                 "rgba(12, 94, 190, 1.000)"
#             ],
#             [
#                 0.16862745098039217,
#                 "rgba(10, 96, 190, 1.000)"
#             ],
#             [
#                 0.17254901960784313,
#                 "rgba(10, 98, 190, 1.000)"
#             ],
#             [
#                 0.17647058823529413,
#                 "rgba(10, 100, 190, 1.000)"
#             ],
#             [
#                 0.1803921568627451,
#                 "rgba(11, 102, 189, 1.000)"
#             ],
#             [
#                 0.1843137254901961,
#                 "rgba(13, 104, 189, 1.000)"
#             ],
#             [
#                 0.18823529411764706,
#                 "rgba(15, 106, 189, 1.000)"
#             ],
#             [
#                 0.19215686274509805,
#                 "rgba(17, 108, 188, 1.000)"
#             ],
#             [
#                 0.19607843137254902,
#                 "rgba(19, 110, 188, 1.000)"
#             ],
#             [
#                 0.2,
#                 "rgba(22, 112, 188, 1.000)"
#             ],
#             [
#                 0.20392156862745098,
#                 "rgba(25, 114, 187, 1.000)"
#             ],
#             [
#                 0.20784313725490197,
#                 "rgba(27, 116, 187, 1.000)"
#             ],
#             [
#                 0.21176470588235294,
#                 "rgba(30, 118, 187, 1.000)"
#             ],
#             [
#                 0.21568627450980393,
#                 "rgba(33, 120, 187, 1.000)"
#             ],
#             [
#                 0.2196078431372549,
#                 "rgba(35, 122, 186, 1.000)"
#             ],
#             [
#                 0.2235294117647059,
#                 "rgba(38, 123, 186, 1.000)"
#             ],
#             [
#                 0.22745098039215686,
#                 "rgba(41, 125, 186, 1.000)"
#             ],
#             [
#                 0.23137254901960785,
#                 "rgba(43, 127, 186, 1.000)"
#             ],
#             [
#                 0.23529411764705882,
#                 "rgba(46, 129, 186, 1.000)"
#             ],
#             [
#                 0.23921568627450981,
#                 "rgba(48, 131, 186, 1.000)"
#             ],
#             [
#                 0.24313725490196078,
#                 "rgba(51, 132, 186, 1.000)"
#             ],
#             [
#                 0.24705882352941178,
#                 "rgba(54, 134, 186, 1.000)"
#             ],
#             [
#                 0.25098039215686274,
#                 "rgba(56, 136, 186, 1.000)"
#             ],
#             [
#                 0.2549019607843137,
#                 "rgba(59, 137, 186, 1.000)"
#             ],
#             [
#                 0.25882352941176473,
#                 "rgba(62, 139, 186, 1.000)"
#             ],
#             [
#                 0.2627450980392157,
#                 "rgba(64, 141, 186, 1.000)

# %%
gr()
@gif for n = Int.(floor.(range(1, length(res_ergo.xs), length=420)))
    plot()
    heatmap(env_data.X, env_data.Y, env_data.W', cmap = :balance; plottype=:wx, clims=(-2, 2))
    for i=1:length(x0s)
        x = [r[i][1] for r in res_ergo.xs[1:n]]
        y = [r[i][2] for r in res_ergo.xs[1:n]]
        plot!(x, y, linewidth=3, color=:black)
    end
    plot!()
end
# Out:
# ┌ Info: Saved animation to
# └ /home/dasc-group/KalebData/PhDResearch/CPS_Project/adaptive-ocean-exploration-sim/tmp.gif
# Plots.AnimatedGif("/home/dasc-group/Kaleb_Data/PhD_Research/CPS_Project/adaptive-ocean-exploration-sim/tmp.gif")

# %%
size(res_ergo.w_hats)
# Out:
# (22,)

# %%
gr()

p2 = heatmap(ngpkf_grid, res_ergo.w_hats[end],colormap=:balance, clims=(-2,2))
# Out:
# UndefVarError: `res_ergo` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[22]:3

# %%
p2 = heatmap(ngpkf_grid, res_ergo.w_hats[end], clims=(0, 1.0), plotstd=true)
# for i=1:length(x0s)
#     x = [r[i][1] for r in res_ergo.xs]
#     y = [r[i][2] for r in res_ergo.xs]
#     plot!(x, y, linewidth=3)
# end
plot!()
# Out:
# Cannot convert Main.NGPKF.NGPKFGrid{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{SVector{2, Float64}}, Hermitian{Float64, Matrix{Float64}}, Main.NGPKF.MaternKernel{Float64}} to series data for plotting
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] _prepare_series_data(x::Main.NGPKF.NGPKFGrid{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{SVector{2, Float64}}, Hermitian{Float64, Matrix{Float64}}, Main.NGPKF.MaternKernel{Float64}})
#     @ RecipesPipeline ~/.julia/packages/RecipesPipeline/BGM3l/src/series.jl:8
#   [3] _series_data_vector(x::Main.NGPKF.NGPKFGrid{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{SVector{2, Float64}}, Hermitian{Float64, Matrix{Float64}}, Main.NGPKF.MaternKernel{Float64}}, plotattributes::Dict{Symbol, Any})
#     @ RecipesPipeline ~/.julia/packages/RecipesPipeline/BGM3l/src/series.jl:36
#   [4] macro expansion
#     @ RecipesPipeline ~/.julia/packages/RecipesPipeline/BGM3l/src/series.jl:128 [inlined]
#   [5] apply_recipe(plotattributes::AbstractDict{Symbol, Any}, ::Type{RecipesPipeline.SliceIt}, x::Any, y::Any, z::Any)
#     @ RecipesPipeline ~/.julia/packages/RecipesBase/BRe07/src/RecipesBase.jl:300
#   [6] _process_userrecipes!(plt::Any, plotattributes::Any, args::Any)
#     @ RecipesPipeline ~/.julia/packages/RecipesPipeline/BGM3l/src/user_recipe.jl:38
#   [7] recipe_pipeline!(plt::Any, plotattributes::Any, args::Any)
#     @ RecipesPipeline ~/.julia/packages/RecipesPipeline/BGM3l/src/RecipesPipeline.jl:72
#   [8] _plot!(plt::Plots.Plot, plotattributes::Any, args::Any)
#     @ Plots ~/.julia/packages/Plots/ju9dp/src/plot.jl:223
#   [9] plot(::Any, ::Vararg{Any}; kw...)
#     @ Plots ~/.julia/packages/Plots/ju9dp/src/plot.jl:102
#  [10] heatmap(::Any, ::Vararg{Any}; kw...)
#     @ Plots ~/.julia/packages/RecipesBase/BRe07/src/RecipesBase.jl:427
#  [11] top-level scope
#     @ In[163]:1

# %%
gr()

p1 = heatmap(ngpkf_grid, res_ergo.w_hats[end],colormap=:balance, clims=(-2,2), plot_min=true)
p2 = heatmap(ngpkf_grid, res_ergo.w_hats[end],colormap=:balance, clims=(-2,2), plot_max=true)
p3 = heatmap(env_data.X, env_data.Y, env_data.W', cmap = :balance; plottype=:wx, clims=(-2, 2))
    
plot(p1, p3, p2, layout = (@layout [a;b; c]), size=[600, 600])
# Out:
# Cannot convert Main.NGPKF.NGPKFGrid{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{SVector{2, Float64}}, Hermitian{Float64, Matrix{Float64}}, Main.NGPKF.MaternKernel{Float64}} to series data for plotting
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] _prepare_series_data(x::Main.NGPKF.NGPKFGrid{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{SVector{2, Float64}}, Hermitian{Float64, Matrix{Float64}}, Main.NGPKF.MaternKernel{Float64}})
#     @ RecipesPipeline ~/.julia/packages/RecipesPipeline/BGM3l/src/series.jl:8
#   [3] _series_data_vector(x::Main.NGPKF.NGPKFGrid{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{SVector{2, Float64}}, Hermitian{Float64, Matrix{Float64}}, Main.NGPKF.MaternKernel{Float64}}, plotattributes::Dict{Symbol, Any})
#     @ RecipesPipeline ~/.julia/packages/RecipesPipeline/BGM3l/src/series.jl:36
#   [4] macro expansion
#     @ RecipesPipeline ~/.julia/packages/RecipesPipeline/BGM3l/src/series.jl:128 [inlined]
#   [5] apply_recipe(plotattributes::AbstractDict{Symbol, Any}, ::Type{RecipesPipeline.SliceIt}, x::Any, y::Any, z::Any)
#     @ RecipesPipeline ~/.julia/packages/RecipesBase/BRe07/src/RecipesBase.jl:300
#   [6] _process_userrecipes!(plt::Any, plotattributes::Any, args::Any)
#     @ RecipesPipeline ~/.julia/packages/RecipesPipeline/BGM3l/src/user_recipe.jl:38
#   [7] recipe_pipeline!(plt::Any, plotattributes::Any, args::Any)
#     @ RecipesPipeline ~/.julia/packages/RecipesPipeline/BGM3l/src/RecipesPipeline.jl:72
#   [8] _plot!(plt::Plots.Plot, plotattributes::Any, args::Any)
#     @ Plots ~/.julia/packages/Plots/ju9dp/src/plot.jl:223
#   [9] plot(::Any, ::Vararg{Any}; kw...)
#     @ Plots ~/.julia/packages/Plots/ju9dp/src/plot.jl:102
#  [10] heatmap(::Any, ::Vararg{Any}; kw...)
#     @ Plots ~/.julia/packages/RecipesBase/BRe07/src/RecipesBase.jl:427
#  [11] top-level scope
#     @ In[164]:3

# %%
using LinearAlgebra, StatsBase

mean_deficit_1 = [mean(map( c -> max(0, 1.0 - c), q )) for q in res_ergo.ergo_q_maps]
# Out:
# 22-element Vector{Float64}:
#  0.4999999999999835
#  0.3859208444097164
#  0.3420285564812052
#  0.31043838697280135
#  0.3015360759172754
#  0.23852780219113978
#  0.2233997982401405
#  0.1995669029982492
#  0.18477761199072684
#  0.16300241002857568
#  0.15808807387009127
#  0.148175766590257
#  0.14284923431530303
#  0.1317802393408716
#  0.122358817047788
#  0.11700718052720259
#  0.11585412639963039
#  0.11287437659594321
#  0.1111097433225107
#  0.1093698015400344
#  0.10478725026803835
#  0.10061380546087144

# %%
ts = range(1, 120, 22)
time = collect(ts)
# Out:
# 22-element Vector{Float64}:
#    1.0
#    6.666666666666667
#   12.333333333333334
#   18.0
#   23.666666666666668
#   29.333333333333332
#   35.0
#   40.666666666666664
#   46.333333333333336
#   52.0
#   57.666666666666664
#   63.333333333333336
#   69.0
#   74.66666666666667
#   80.33333333333333
#   86.0
#   91.66666666666667
#   97.33333333333333
#  103.0
#  108.66666666666667
#  114.33333333333333
#  120.0

# %%
# plot(res_ergo.w_hat_ts, mean_deficit_1, marker=:dot)
gr()
plot()
plot!(time, mean_deficit_1, marker=:dot)
ylabel!("Clarity Deficit[0,1]")
xlabel!("Time [min]")
ylims!(0., 0.6)
